# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# 'D:\\ml\\projects\\clustering'

# %%
df=pd.read_csv(os.path.join('data','data.csv'))
df.head()
# Out:
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1   1 -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2   2  0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3   3 -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4   4 -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
#
#    f_07  f_08  ...      f_19      f_20      f_21      f_22      f_23  \
# 0     2    13  ... -0.478412 -0.757002 -0.763635 -1.090369  1.142641
# 1     2     3  ... -0.428791 -0.089908 -1.784204 -0.839474  0.459685
# 2     5    11  ... -0.413534 -1.602377  1.190984  3.267116 -0.088322
# 3     6     2  ...  0.619283  1.287801  0.532837  1.036631 -2.041828
# 4     8     7  ... -1.628830 -0.434948  0.322505  0.284326 -2.438365
#
#        f_24      f_25      f_26      f_27      f_28
# ...

# %%
from pycaret.clustering import *
model=setup(df,normalize=True)
# Out:
# <style type="text/css">
# #T_e3c50_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e3c50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3c50_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e3c50_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3c50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3c50_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e3c50_row0_col1" class="data row0 col1" >5913</td>
#     </tr>
#     <tr>
#       <th id="T_e3c50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3c50_row1_col0" class="data row1 col0" >Original Data</td>
#       <td id="T_e3c50_row1_col1" class="data row1 col1" >(98000, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_e3c50_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
k_means=create_model('kmeans')
# Out:
#    Silhouette  Calinski-Harabasz  Davies-Bouldin  Homogeneity  Rand Index  \
# 0      0.0369          3152.2393          4.2707            0           0
#
#    Completeness
# 0             0

# %%
plot_model(k_means, plot = 'elbow')

# %%
result = assign_model(k_means)
result.head(10)
# Out:
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1   1 -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2   2  0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3   3 -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4   4 -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
# 5   5 -0.888945 -1.121026  0.988608  0.224778  1.655074 -1.274271  0.371443
# 6   6 -0.096137 -0.247528 -0.642176 -0.534849  1.051045  0.257412 -2.129200
# 7   7 -0.908615  0.065319 -0.427002 -0.392070  1.135532  0.797638 -0.510480
# 8   8  0.997730 -1.153765 -0.908964  0.984962  1.176252 -0.061570 -1.015247
# 9   9 -0.641308  0.376707 -0.427771  0.802239 -1.049559 -0.215596 -1.277036
#
#    f_07  f_08  ...      f_20      f_21      f_22      f_23      f_24  \
# ...

# %%
result.head(30)
# Out:
#     id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0    0 -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1    1 -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2    2  0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3    3 -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4    4 -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
# 5    5 -0.888945 -1.121026  0.988608  0.224778  1.655074 -1.274271  0.371443
# 6    6 -0.096137 -0.247528 -0.642176 -0.534849  1.051045  0.257412 -2.129200
# 7    7 -0.908615  0.065319 -0.427002 -0.392070  1.135532  0.797638 -0.510480
# 8    8  0.997730 -1.153765 -0.908964  0.984962  1.176252 -0.061570 -1.015247
# 9    9 -0.641308  0.376707 -0.427771  0.802239 -1.049559 -0.215596 -1.277036
# 10  10  1.062159 -0.396084 -1.220709 -0.821185 -0.402880 -0.784123 -1.721263
# ...

# %%
result.rename(columns={'Cluster':'Predicted'},inplace=True)
result.replace({'Cluster 0': 0, 'Cluster 1': 1,'Cluster 2': 2,'Cluster 3': 3,'Cluster 4': 4}, inplace=True)

# %%
result.head()
# Out:
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1   1 -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2   2  0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3   3 -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4   4 -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
#
#    f_07  f_08  ...      f_20      f_21      f_22      f_23      f_24  \
# 0     2    13  ... -0.757002 -0.763635 -1.090369  1.142641 -0.884274
# 1     2     3  ... -0.089908 -1.784204 -0.839474  0.459685  1.759412
# 2     5    11  ... -1.602377  1.190984  3.267116 -0.088322 -2.168635
# 3     6     2  ...  1.287801  0.532837  1.036631 -2.041828  1.440490
# 4     8     7  ... -0.434948  0.322505  0.284326 -2.438365  1.473930
#
#        f_25      f_26      f_27      f_28  Predicted
# ...

# %%
x=result.iloc[:,0]
x.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64

# %%
y=result.iloc[:,-1]
y
# Out:
# 0        3
# 1        1
# 2        3
# 3        2
# 4        1
#         ..
# 97995    1
# 97996    1
# 97997    0
# 97998    2
# 97999    3
# Name: Predicted, Length: 98000, dtype: int64

# %%
x=pd.DataFrame(x, columns = ['id'])
x.head()
# Out:
#    id
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4

# %%
y=pd.DataFrame(y, columns = ['Predicted'])
y.head()
# Out:
#    Predicted
# 0          3
# 1          1
# 2          3
# 3          2
# 4          1

# %%
x.to_csv('file1.csv')
y.to_csv('file2.csv')
